# %%
import pandas as pd
rows = [ { 'col1' : 0.5 , 'col2'  : 'schtroumph' } ,
{ 'col1'  : 0.6 , 'col2'  : 'sch t roumphe t te' } ]

# %%
rows
# Out:
# [{'col1': 0.5, 'col2': 'schtroumph'},
#  {'col1': 0.6, 'col2': 'sch t roumphe t te'}]

# %%
df= pd.DataFrame (rows)

# %%
import os

# %%
os.getcwd( )
# Out:
# '/content'

# %% [markdown]
# affichage fichier csv

# %%
pd.read_csv('temperature.csv')
# Out:
#        record_id  month  day  year  AverageTemperatureFahr  \
# 0         474376      1    1  1853                     NaN
# 1         474377      2    1  1853                     NaN
# 2         474378      3    1  1853                     NaN
# 3         474379      4    1  1853                     NaN
# 4         474380      5    1  1853                     NaN
# ...          ...    ...  ...   ...                     ...
# 48465    8258726      5    1  2013                 55.0544
# 48466    8258727      6    1  2013                 61.1672
# 48467    8258728      7    1  2013                 66.7706
# 48468    8258729      8    1  2013                 64.5656
# 48469    8258730      9    1  2013                     NaN
#
#        AverageTemperatureUncertaintyFahr      City country_id      Country  \
# 0                                    NaN  Auckland        NEW  New Zealand
# 1                                    NaN  Auckland        NEW  New Zealand
# ...

# %% [markdown]
# tous les lignes de la 1eme colonne (type float)

# %%
df['col1']
# Out:
# 0    0.5
# 1    0.6
# Name: col1, dtype: float64

# %% [markdown]
# tous les lignes de la 2eme colonne (type obj)

# %%
df['col2']
# Out:
# 0            schtroumph
# 1    sch t roumphe t te
# Name: col2, dtype: object

# %%
df[['col1','col2']]
# Out:
#    col1                col2
# 0   0.5          schtroumph
# 1   0.6  sch t roumphe t te

# %% [markdown]
# 1 ligne

# %%
df[:1]
# Out:
#    col1        col2
# 0   0.5  schtroumph

# %% [markdown]
# col1 de ligne avec index 0

# %%
df.loc [ 0 , 'col1' ]
# Out:
# np.float64(0.5)

# %%
df.iloc[0,0]
# Out:
# np.float64(0.5)

# %%
dfi = df.set_index('col2')

# %%
dfi
# Out:
#                     col1
# col2
# schtroumph           0.5
# sch t roumphe t te   0.6

# %%
dfii = df.set_index('col1')

# %%
dfii
# Out:
#                     col2
# col1
# 0.5           schtroumph
# 0.6   sch t roumphe t te

# %%
dfii.columns
# Out:
# Index(['col2'], dtype='object')

# %%
df.columns=['valeur','nom']

# %%
df
# Out:
#    valeur                 nom
# 0     0.5          schtroumph
# 1     0.6  sch t roumphe t te

# %% [markdown]
# lien avec numpy

# %%
df.values
# Out:
# array([[0.5, 'schtroumph'],
#        [0.6, 'sch t roumphe t te']], dtype=object)

# %%
df[['valeur']].values
# Out:
# array([[0.5],
#        [0.6]])

# %% [markdown]
# NaN (absence val)

# %%
rows = [ { 'col1' : 0.5 , 'col2'  : 'schtroumph' } ,{ 'col2' :
'sch t roumphe t te' } ]
d= pd.DataFrame ( rows )

# %%
d
# Out:
#    col1                col2
# 0   0.5          schtroumph
# 1   NaN  sch t roumphe t te

# %% [markdown]
# creation col

# %%
import numpy as numpy

# %%
df [ 'sup055' ] = df [ 'valeur' ] >= 0.55
print( df )
# Out:
#    valeur                 nom  sup055  sup055+
# 0     0.5          schtroumph   False      0.5
# 1     0.6  sch t roumphe t te    True      1.6

# %%
df [ 'sup055' ] = ( df [ 'valeur' ] >= 0.55 ).astype (numpy .int64 )
print( df )
# Out:
#    valeur                 nom  sup055  sup055+
# 0     0.5          schtroumph       0      0.5
# 1     0.6  sch t roumphe t te       1      1.6

# %%
df [ 'sup055+' ] = df [ 'valeur' ] + df [ 'sup055']
print( df )
# Out:
#    valeur                 nom  sup055  sup055+
# 0     0.5          schtroumph       0      0.5
# 1     0.6  sch t roumphe t te       1      1.6
